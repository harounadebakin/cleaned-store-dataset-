# %% [markdown]
# # Data Cleaning and Data Wrangling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
storedata = pd.read_csv(r"C:\Users\User\Documents\Skilharvest\storedata.csv")

# %%
storedata.head(5)
# Out:
#                             Town Country  Store ID Manager name  Staff  \
# 0   Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                       Stamford      UK      1544         Ella      8
# 2                        Skipton      UK      2039    Valentina     -2
# 3                       Stratton      UK      2055      Antonia      7
# 4                     Shepperton      UK      2141      Gabriel      7
#
#    Floor Space  Window Car park  Demographic score         Location  \
# 0        18526     121      Yes                 10      Retail Park
# 1        18569     121      Yes                 11  Shopping Centre
# 2        12288     105       No                 12      Retail Park
# 3        17092     117       No                 14      High Street
# 4        11307     103       No                 18      Retail Park
#
#    40min population  30 min population  20 min population  10 min population  \
# ...

# %%
storedata.tail(5)
# Out:
#                 Town Country  Store ID Manager name  Staff  Floor Space  \
# 131   South Benfleet      UK     96853      Vit�ria      7        14120
# 132            Sandy      UK     96858       Mat�as      6        11205
# 133        Sheerness      UK     98062      Gustavo      7        16190
# 134          Salford      UK     98923       Rafael      6        15516
# 135       Stapleford      UK     99854          Lea      9        14468
#
#      Window Car park  Demographic score         Location  40min population  \
# 131     110      Yes                 13      Retail Park           1665074
# 132     103       No                 15  Shopping Centre           1657769
# 133     115       No                 19  Shopping Centre           1407456
# 134     113       No                 17      High Street           1451087
# 135     111      Yes                 18      High Street           1706344
#
#      30 min population  20 min population  10 min population  Store age  \
# ...

# %%
storedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Town                136 non-null    object
#  1   Country             136 non-null    object
#  2   Store ID            136 non-null    int64
#  3   Manager name        136 non-null    object
#  4   Staff               136 non-null    int64
#  5   Floor Space         136 non-null    int64
#  6   Window              136 non-null    int64
#  7   Car park            136 non-null    object
#  8   Demographic score   136 non-null    int64
#  9   Location            136 non-null    object
#  10  40min population    136 non-null    int64
#  11  30 min population   136 non-null    int64
#  12  20 min population   136 non-null    int64
#  13  10 min population   136 non-null    int64
#  14  Store age           136 non-null    int64
#  15  Clearance space     136 non-null    int64
# ...

# %%
storedata.describe()
# Out:
#            Store ID       Staff   Floor Space      Window  Demographic score  \
# count    136.000000  136.000000    136.000000  136.000000         136.000000
# mean   52172.580882   13.352941  15024.095588  112.044118          14.463235
# std    28725.990237   56.592439   2761.801921    6.884085           2.874944
# min     1437.000000   -2.000000  10072.000000  100.000000          10.000000
# 25%    24707.250000    6.000000  12793.000000  106.750000          12.000000
# 50%    56011.500000    7.000000  14596.500000  111.000000          14.500000
# 75%    76870.500000    8.000000  17543.750000  118.000000          17.000000
# max    99854.000000  600.000000  19869.000000  124.000000          19.000000
#
#        40min population  30 min population  20 min population  \
# count      1.360000e+02       1.360000e+02       1.360000e+02
# mean       1.487374e+06       1.249870e+06       1.134533e+06
# std        2.804989e+05       2.160875e+05       1.490280e+05
# ...

# %%
storedata.columns
# Out:
# Index(['Town', 'Country', 'Store ID', 'Manager name', 'Staff', 'Floor Space',
#        'Window', 'Car park', 'Demographic score', 'Location',
#        '40min population', '30 min population', '20 min population',
#        '10 min population', 'Store age', 'Clearance space',
#        'Competition number', 'Competition score', 'Performance'],
#       dtype='object')

# %%
storedata.shape
# Out:
# (136, 19)

# %%
storedata.isna().sum()
# Out:
# Town                  0
# Country               0
# Store ID              0
# Manager name          0
# Staff                 0
# Floor Space           0
# Window                0
# Car park              0
# Demographic score     0
# Location              0
# 40min population      0
# 30 min population     0
# 20 min population     0
# 10 min population     0
# Store age             0
# Clearance space       0
# Competition number    0
# Competition score     0
# Performance           0
# dtype: int64

# %%
storedata.drop("Store ID", axis=1, inplace=True)

# %%
storedata.Staff.hist()
# Out:
# <Axes: >

# %%
storedata.sample(3)
# Out:
#                  Town Country Manager name  Staff  Floor Space  Window  \
# 64       Shoeburyness      UK  Christopher      6        12363     105
# 83         Sheringham      UK        Ethan      5        16652     116
# 119   St Columb Major      UK        Tyler      6        13532     108
#
#     Car park  Demographic score         Location  40min population  \
# 64       Yes                 12  Shopping Centre           1090251
# 83         N                 12      High Street           1931932
# 119      Yes                 16  Shopping Centre           1145543
#
#      30 min population  20 min population  10 min population  Store age  \
# 64             1085936            1056470            1028772          6
# 83             1547591            1547000            1298080          6
# 119            1117032            1011454            1005261         11
#
#      Clearance space  Competition number  Competition score Performance
# ...

# %%
storedata.columns
# Out:
# Index(['Town', 'Country', 'Manager name', 'Staff', 'Floor Space', 'Window',
#        'Car park', 'Demographic score', 'Location', '40min population',
#        '30 min population', '20 min population', '10 min population',
#        'Store age', 'Clearance space', 'Competition number',
#        'Competition score', 'Performance'],
#       dtype='object')

# %%
storedata.drop("Manager name", axis=1, inplace=True)

# %%
storedata.Location
# Out:
# 0          Retail Park
# 1      Shopping Centre
# 2          Retail Park
# 3          High Street
# 4          Retail Park
#             ...
# 131        Retail Park
# 132    Shopping Centre
# 133    Shopping Centre
# 134        High Street
# 135        High Street
# Name: Location, Length: 136, dtype: object

# %%
storedata.Location.unique()
# Out:
# array(['Retail Park', 'Shopping Centre', 'High Street', 'Village'],
#       dtype=object)

# %% [markdown]
# # Data Preprocessing, Feature Selection and Engineering

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
storedata.Location = le.fit_transform(storedata.Location)

# %%
storedata.head(5)
# Out:
#                             Town Country  Staff  Floor Space  Window Car park  \
# 0   Swinton (Greater Manchester)      UK      9        18526     121      Yes
# 1                       Stamford      UK      8        18569     121      Yes
# 2                        Skipton      UK     -2        12288     105       No
# 3                       Stratton      UK      7        17092     117       No
# 4                     Shepperton      UK      7        11307     103       No
#
#    Demographic score  Location  40min population  30 min population  \
# 0                 10         1           1288374            1138224
# 1                 11         2           1086225            1015321
# 2                 12         1           1595638            1281661
# 3                 14         0           1179395            1022959
# 4                 18         1           1398558            1085170
#
#    20 min population  10 min population  Store age  Clearance space  \
# ...

# %%
storedata.Country
# Out:
# 0      UK
# 1      UK
# 2      UK
# 3      UK
# 4      UK
#        ..
# 131    UK
# 132    UK
# 133    UK
# 134    UK
# 135    UK
# Name: Country, Length: 136, dtype: object

# %%
storedata.Country.unique()
# Out:
# array(['UK', 'France'], dtype=object)

# %%
storedata.Country = le.fit_transform(storedata.Country)

# %%
storedata.Country.unique()
# Out:
# array([1, 0])

# %%
storedata.Town.unique()
# Out:
# array([' Swinton (Greater Manchester)', ' Stamford', ' Skipton',
#        ' Stratton', ' Shepperton', ' Southwell',
#        ' Swinton (South Yorkshire)', ' Sowerby Bridge', ' Sheffield',
#        ' Stanley', ' Shepshed', ' Staines', ' Sutton', ' Stafford',
#        ' Sawbridgeworth', ' Stocksbridge', ' Salcombe', ' Southminster',
#        ' Slough', ' Sedgley', ' St Mawes', ' Sudbury', ' Steyning',
#        ' Southampton', ' Snaith', ' Sampford Courtenay', ' Skelmersdale',
#        ' Scunthorpe', ' Sunderland', ' Streatham', ' Saxmundham',
#        ' Sandiacre', ' Stretford', ' St Austell', ' Stalbridge',
#        ' Southwick', ' Shefford', ' Stanford-le-Hope', ' Swindon',
#        ' Stainforth', ' St Helens', ' Stourbridge', ' Swadlincote',
#        ' Sale', ' Seaham', ' Southwold', ' Shanklin', ' South Shields',
#        ' Southport', ' Stalham', ' Shaw & Crompton', ' South Elmsall',
#        ' St Blazey', ' Sherborne', ' Smethwick', ' Stow-on-the-Wold',
# ...

# %%
storedata.Town.value_counts().shape
# Out:
# (136,)

# %%
storedata.drop("Town", axis = 1, inplace=True)

# %%
storedata.sample(3)
# Out:
#      Country  Staff  Floor Space  Window Car park  Demographic score  \
# 23         1      6        16219     115      Yes                 13
# 120        1      5        14087     110      Yes                 17
# 82         1      6        12856     107       No                 13
#
#      Location  40min population  30 min population  20 min population  \
# 23          2           1759951            1635794            1232915
# 120         0           1997044            1804663            1461181
# 82          2           1481703            1448279            1076634
#
#      10 min population  Store age  Clearance space  Competition number  \
# 23             1158507          5              273                  16
# 120            1290194          3              264                  13
# 82             1036922          5              240                  12
#
#      Competition score Performance
# 23                  18        Good
# 120                 17         Bad
# ...

# %%
storedata.Performance = le.fit_transform(storedata.Performance)

# %%
storedata.sample(3)
# Out:
#      Country  Staff  Floor Space  Window Car park  Demographic score  \
# 76         1      7        10072     100       No                 15
# 127        1      6        11820     104      Yes                 11
# 68         1      6        13709     109      Yes                 11
#
#      Location  40min population  30 min population  20 min population  \
# 76          1           1258330            1256349            1184882
# 127         2           1557600            1413964            1249072
# 68          0           1061935            1006165            1002529
#
#      10 min population  Store age  Clearance space  Competition number  \
# 76             1072598          5              200                  14
# 127            1191086          5              211                  18
# 68             1001991          8              291                  14
#
#      Competition score  Performance
# 76                  12            0
# 127                 18            1
# ...

# %%
storedata.columns
# Out:
# Index(['Country', 'Staff', 'Floor Space', 'Window', 'Car park',
#        'Demographic score', 'Location', '40min population',
#        '30 min population', '20 min population', '10 min population',
#        'Store age', 'Clearance space', 'Competition number',
#        'Competition score', 'Performance'],
#       dtype='object')

# %%
storedata[(storedata['Car park']=="No") & (storedata['Performance']==1)].shape
# Out:
# (14, 16)

# %%
storedata[(storedata['Car park']=="Yes") & (storedata['Performance']==1)].shape
# Out:
# (51, 16)

# %%
storedata[(storedata['Car park']=="No") & (storedata['Performance']==0)].shape
# Out:
# (21, 16)

# %%
storedata['Car park'] = le.fit_transform(storedata['Car park'])

# %%
storedata.corr()
# Out:
#                      Country     Staff  Floor Space    Window  Car park  \
# Country             1.000000  0.013765     0.070044  0.072035  0.050612
# Staff               0.013765  1.000000     0.076039  0.077630  0.073654
# Floor Space         0.070044  0.076039     1.000000  0.999208  0.083369
# Window              0.072035  0.077630     0.999208  1.000000  0.082809
# Car park            0.050612  0.073654     0.083369  0.082809  1.000000
# Demographic score  -0.044220 -0.057831     0.038187  0.038633 -0.047896
# Location            0.088340  0.126064     0.011581  0.012063  0.070720
# 40min population   -0.032546 -0.098366     0.051918  0.053228 -0.077582
# 30 min population  -0.095203 -0.024631    -0.032199 -0.028688 -0.098287
# 20 min population   0.027442 -0.056310    -0.046161 -0.042441 -0.018761
# 10 min population   0.051530 -0.006601    -0.096698 -0.091651 -0.044656
# Store age           0.044839 -0.172655    -0.049285 -0.048992 -0.139507
# ...

# %%
threshold = 0.1
features = storedata.corr()['Performance'].abs()[storedata.corr()['Performance'].abs() >= threshold]
features
# Out:
# Country               0.123979
# Staff                 0.124331
# Floor Space           0.267429
# Window                0.274381
# Car park              0.158072
# Demographic score     0.117908
# Location              0.350950
# Clearance space       0.257304
# Competition number    0.209215
# Competition score     0.345618
# Performance           1.000000
# Name: Performance, dtype: float64

# %%
features = pd.DataFrame(features).T

# %%
features
# Out:
#               Country     Staff  Floor Space    Window  Car park  \
# Performance  0.123979  0.124331     0.267429  0.274381  0.158072
#
#              Demographic score  Location  Clearance space  Competition number  \
# Performance           0.117908   0.35095         0.257304            0.209215
#
#              Competition score  Performance
# Performance           0.345618          1.0

# %%
features.columns
# Out:
# Index(['Country', 'Staff', 'Floor Space', 'Window', 'Car park',
#        'Demographic score', 'Location', 'Clearance space',
#        'Competition number', 'Competition score', 'Performance'],
#       dtype='object')

# %%
features_selected = storedata[['Country', 'Staff', 'Floor Space', 'Window', 'Car park',
       'Demographic score', 'Location', 'Clearance space',
       'Competition number', 'Competition score', 'Performance']]

# %%
features_selected.head(4)
# Out:
#    Country  Staff  Floor Space  Window  Car park  Demographic score  Location  \
# 0        1      9        18526     121         3                 10         1
# 1        1      8        18569     121         3                 11         2
# 2        1     -2        12288     105         1                 12         1
# 3        1      7        17092     117         1                 14         0
#
#    Clearance space  Competition number  Competition score  Performance
# 0              238                  16                 16            1
# 1              384                  15                 19            1
# 2              219                  13                 18            0
# 3              261                  15                 12            0

# %% [markdown]
# # Splitting Data

# %%
features_selected.shape
# Out:
# (136, 11)

# %%
x = features_selected.iloc[:, :10]
x
# Out:
#      Country  Staff  Floor Space  Window  Car park  Demographic score  \
# 0          1      9        18526     121         3                 10
# 1          1      8        18569     121         3                 11
# 2          1     -2        12288     105         1                 12
# 3          1      7        17092     117         1                 14
# 4          1      7        11307     103         1                 18
# ..       ...    ...          ...     ...       ...                ...
# 131        1      7        14120     110         3                 13
# 132        1      6        11205     103         1                 15
# 133        1      7        16190     115         1                 19
# 134        1      6        15516     113         1                 17
# 135        1      9        14468     111         3                 18
#
#      Location  Clearance space  Competition number  Competition score
# ...

# %%
y = features_selected.Performance

# %% [markdown]
# # Model Selection

# %%
pip install lazypredict
# Out:
# ...
#
#   Using cached lazypredict-0.2.12-py2.py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached lightgbm-4.3.0-py3-none-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# ...
# Using cached lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached lightgbm-4.3.0-py3-none-win_amd64.whl (1.3 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 640.0 kB/s eta 0:02:36
#    ---------------------------------------- 0.0/99.8 MB 640.0 kB/s eta 0:02:36
#    ---------------------------------------- 0.0/99.8 MB 640.0 kB/s eta 0:02:36
# ...

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyClassifier
lc = LazyClassifier()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from lazypredict.Supervised import LazyClassifier
#
# File C:\Python\Python312\Lib\site-packages\lazypredict\Supervised.py:98
#      89 # CLASSIFIERS.append(('CatBoostClassifier',catboost.CatBoostClassifier))
#      91 numeric_transformer = Pipeline(
#      92     steps=[("imputer", SimpleImputer(strategy="mean")), ("scaler", StandardScaler())]
#      93 )
#      95 categorical_transformer_low = Pipeline(
#      96     steps=[
#      97         ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
# ---> 98         ("encoding", OneHotEncoder(handle_unknown="ignore", sparse=False)),
#      99     ]
#     100 )
#     102 categorical_transformer_high = Pipeline(
#     103     steps=[
#     104         ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
#    (...)
# ...

# %%
   OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
OH_encoder = OneHotEncoder(handle_unknown='ignore')

# %%
pip install -U scikit-learn==0.20
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scikit-learn==0.20
#   Using cached scikit-learn-0.20.0.tar.gz (28.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [26 lines of output]
#   <string>:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   Partial import of sklearn during the build process.
#   Traceback (most recent call last):
# ...
